# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
nc_file = ('climatology-tas-monthly-mean_cru_monthly_cru-ts4.05-climatology_mean_1991-2020.nc')
ds=xr.open_dataset(nc_file)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                       (time: 12, lat: 360, lon: 720, bnds: 2)
# Coordinates:
#   * time                          (time) datetime64[ns] 1991-01-16 ... 1991-1...
#   * lat                           (lat) float32 -89.75 -89.25 ... 89.25 89.75
#   * lon                           (lon) float32 -179.8 -179.2 ... 179.2 179.8
#   * bnds                          (bnds) int32 0 1
# Data variables:
#     climatology-tas-monthly-mean  (time, lat, lon) float32 ...
#     lon_bnds                      (lon, bnds) float64 ...
#     lat_bnds                      (lat, bnds) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Mean Temperature
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:tmp.2103041709.dtb
#     history:      Fri  5 Mar 13:25:53 GMT 2021 : User harry : Program makegri...
# ...

# %%
ds['climatology-tas-monthly-mean']
# Out:
# <xarray.DataArray 'climatology-tas-monthly-mean' (time: 12, lat: 360, lon: 720)>
# [3110400 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1991-01-16 1991-02-16 ... 1991-12-16
#   * lat      (lat) float32 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * lon      (lon) float32 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
# Attributes:
#     correlation_decay_distance:  1200.0
#     units:                       degC
#     long_name:                   near-surface temperature
#     time_op_ncl:                 Climatology: 30 years

# %%
plt.contourf(ds['climatology-tas-monthly-mean'][0,:,:])
plt.colorbar()
